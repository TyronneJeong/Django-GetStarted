# %% [markdown]
# # 최종과제완성
#
# 최종 과제 완성을 위하여 질문지와 투표지를 모두 작성하여 준비한다.

# %% [markdown]
# ## 1.질문지등록
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 2. 선택지 등록
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 3. Detail Template 의 내용을 보완한다.
# 사용자가 선택한 값을 vote URL 로 전송하여 사용자가 선택한 값을 확인 시켜준다. 별도의 저장 기능은 없다.
#
# ```python
# <h1>{{ question.question_text }}</h1>
#
# <!-- if error message exists start -->
# {% if error_message%}
# <p><strong>{{ error_message }}</strong></p>
# {% endif %}
# <!-- if error message exists end -->
#
# <form action="{% url 'polls:vote' question.id %}" method="post">
# {% csrf_token %}
#
# {% for choice in question.choice_set.all %}
# 	<input type="radio" name="choice" id="choice{{ forloop.counter }}" value="{{ choice.id }}">
# 	<label for="choice{{ forloop.counter }}"> {{ choice.choice_text }} </label><br>
# {% endfor %}
# <input type="submit" value="Vote">
# </form>
# ```

# %% [markdown]
# #### 정상적인 호출 결과 확인
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 투표 내용 확인 페이지 이동
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 4. 저장 기능의 구현
# 투표 결과를 저장하는 기능을 구현해본다.
#
# ```python
# from django.http import HttpResponse, HttpResponseRedirect
# from django.shortcuts import get_object_or_404, render
# from django.urls import reverse
#
# def vote(request, question_id):
#     question = get_object_or_404(Question, pk=question_id)
#     try:
#         selected_choice = question.choice_set.get(pk=request.POST['choice'])
#     except (KeyError, Choice.DoesNotExist):
#         return render(request, 'polls/detail.html', {
#             'question':question,
#             'error_message': "You did not select a choice.",
#         })
#     else:
#         selected_choice.vote += 1
#         selected_choice.save()
#         return HttpResponseRedirect(reverse('polls:results', args=(question.id,)))
# ```

# %%
# vote 메소드 작업 내용 확인
# !tail --l 14 ../polls/views.py
# Out:
#
# def vote(request, question_id):
#     question = get_object_or_404(Question, pk=question_id)
#     try:
#         selected_choice = question.choice_set.get(pk=request.POST['choice'])
#     except (KeyError, Choice.DoesNotExist):
#         return render(request, 'polls/detail.html', {
#             'question':question,
#             'error_message': "You did not select a choice.",
#         })
#     else:
#         selected_choice.vote += 1
#         selected_choice.save()
#         return HttpResponseRedirect(reverse('polls:results', args=(question.id,)))

# %% [markdown]
# ## 5. 결과확인 화면 구현
# 수집된 결과를 보여주는 화면을 구현한다.
#
# ```python
# from django.shortcuts import get_object_or_404, render
# def results(request, question_id):
#     question = get_object_or_404(Question, pk=question_id)
#     return render(request, 'polls/results.html', {'question':question})
# ```

# %%
# 랜더링 시킬 Template
# !cat ../polls/templates/polls/results.html
# Out:
# <h1>{{ question.question_text }}</h1>
#
# <ul>
# {% for choice in question.choice_set.all %}
# 	<li>
# 		{{ choice.choice_text }} -- {{ choice.votes }} vote{{ choice.votes|pluralize }}
# 	</li>
# {% endfor %}
# </ul>
#
# <a href="{% url 'polls:detail' question.id %}">Vote again?</a>

# %% [markdown]
# ## 최종 결과 확인
# ![image.png](attachment:image.png)
#
# #### pluralize
# 변수 값의 크기에 따라 단수 혹은 복수로 접미사를 붙여주는 옵션
